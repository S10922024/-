# %% [markdown]
# <a href="https://colab.research.google.com/github/S10922024/-/blob/master/%E3%80%8CAssessments_7%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("readr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(readr)
library(ggplot2)

# %%
minerincomedata<- read.csv("123.csv")

# %%
str(minerincomedata)
# Out:
# 'data.frame':	216 obs. of  7 variables:
#  $ 年度        : int  2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 ...
#  $ 職類別      : chr  "主管及監督人員" "高階主管(總經理及總執行長)" "中階主管(經理)" "監督人員(含現場及辦公室主任、科/股長)" ...
#  $ 行業別      : chr  "礦業及土石採取業各業" "礦業及土石採取業各業" "礦業及土石採取業各業" "礦業及土石採取業各業" ...
#  $ 受僱員工人數: chr  "266" "14" "82" "170" ...
#  $ 總薪資      : chr  "130785" "129852" "122199" "135003" ...
#  $ 經常性薪資  : chr  "72705" "99204" "80370" "66826" ...
#  $ 非經常性薪資: chr  "58080" "30648" "41829" "68177" ...

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable = TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
ggplot(minerincomedata, aes(x =行業別 , y =經常性薪資 )) + geom_point()
# Out:
# plot without title

# %%
ggplot(minerincomedata, aes(x = 經常性薪資)) + geom_bar()
# Out:
# plot without title

# %%
qplot(職類別, 經常性薪資, data = minerincomedata, color = 行業別)
# Out:
# plot without title

# %%
qplot(總薪資, data = minerincomedata, fill = 行業別)
# Out:
# plot without title

# %%
qplot(經常性薪資, 職類別, data = minerincomedata, facets = 行業別 ~ .)
# Out:
# plot without title
